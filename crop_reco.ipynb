# %%
import pandas as pd
crop = pd.read_csv("Crop_recommendation.csv")
crop.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
crop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %%
crop.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
crop['label'].value_counts()
# Out:
# label
# rice           100
# maize          100
# chickpea       100
# kidneybeans    100
# pigeonpeas     100
# mothbeans      100
# mungbean       100
# blackgram      100
# lentil         100
# pomegranate    100
# banana         100
# mango          100
# grapes         100
# watermelon     100
# muskmelon      100
# apple          100
# orange         100
# papaya         100
# coconut        100
# cotton         100
# jute           100
# coffee         100
# Name: count, dtype: int64

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split

# Load data
df = pd.read_csv('Crop_recommendation.csv')

# Inspect and handle missing values
df = df.dropna()  # Or use df.fillna(df.mean())

# %%
# Encode target label
labelencoder = LabelEncoder()
df['label'] = labelencoder.fit_transform(df['label'])

# %%
# Separate features and target
X = df.drop(['label'], axis=1)
y = df['label']

# %%
# Feature scaling
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Split data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# Initialize and train model
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Predict
y_pred = model.predict(X_test)

# Evaluate
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9931818181818182
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        23
#            1       1.00      1.00      1.00        21
#            2       1.00      1.00      1.00        20
#            3       1.00      1.00      1.00        26
#            4       1.00      1.00      1.00        27
#            5       1.00      1.00      1.00        17
#            6       1.00      1.00      1.00        17
#            7       1.00      1.00      1.00        14
#            8       0.92      1.00      0.96        23
#            9       1.00      1.00      1.00        20
#           10       0.92      1.00      0.96        11
#           11       1.00      1.00      1.00        21
#           12       1.00      1.00      1.00        19
#           13       1.00      0.96      0.98        24
#           14       1.00      1.00      1.00        19
#           15       1.00      1.00      1.00        17
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, classification_report

# Define hyperparameter grid
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'criterion': ['gini', 'entropy']
}

# Initialize model
rf = RandomForestClassifier(random_state=42)

# Initialize GridSearchCV
grid_search = GridSearchCV(estimator=rf,
                           param_grid=param_grid,
                           cv=3,
                           n_jobs=-1,
                           verbose=2)

# Fit to training set
grid_search.fit(X_train, y_train)

# Best estimator
best_model = grid_search.best_estimator_

# Prediction and evaluation
y_pred = best_model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

print("Optimized Accuracy:", accuracy)
print("Best Hyperparameters:", grid_search.best_params_)
print(classification_report(y_test, y_pred))
# Out:
# Fitting 3 folds for each of 216 candidates, totalling 648 fits
# Optimized Accuracy: 0.9931818181818182
# Best Hyperparameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        23
#            1       1.00      1.00      1.00        21
#            2       1.00      1.00      1.00        20
#            3       1.00      1.00      1.00        26
#            4       1.00      1.00      1.00        27
#            5       1.00      1.00      1.00        17
#            6       1.00      1.00      1.00        17
#            7       1.00      1.00      1.00        14
#            8       0.92      1.00      0.96        23
#            9       1.00      1.00      1.00        20
#           10       0.92      1.00      0.96        11
#           11       1.00      1.00      1.00        21
# ...

# %%
import joblib

# After training; 'best_model' is your optimized model
joblib.dump(best_model, 'crop_recommendation_model.pkl')
# Out:
# ['crop_recommendation_model.pkl']

# %%
import joblib
best_model = joblib.load('crop_recommendation_model.pkl')

# %%
import joblib
import numpy as np

# Load trained model, scaler, and label encoder
best_model = joblib.load('crop_recommendation_model.pkl')
scaler = joblib.load('scaler.pkl')
label_encoder = joblib.load('label_encoder.pkl')

def test_model_with_inputs(N, P, K, temperature, humidity, ph, rainfall):
    # Prepare input with proper feature names
    input_dict = {
        'N': [N], 'P': [P], 'K': [K],
        'temperature': [temperature],
        'humidity': [humidity],
        'ph': [ph],
        'rainfall': [rainfall]
    }
    input_df = pd.DataFrame(input_dict)
    input_scaled = scaler.transform(input_df)
    prediction = best_model.predict(input_scaled)
    prediction_proba = best_model.predict_proba(input_scaled)
    predicted_crop = label_encoder.inverse_transform(prediction)[0]
    confidence = np.max(prediction_proba) * 100
    return predicted_crop, confidence


print("N=90, P=42, K=43, temp=20.88, humidity=82, pH=6.5, rainfall=202.94")
crop1, conf1 = test_model_with_inputs(90, 42, 43, 20.88, 82, 6.5, 202.94)
print(f"Predicted Crop: {crop1} (Confidence: {conf1:.2f}%)")
print()

print("N=78, P=48, K=22, temp=23.1, humidity=63.7, pH=6.9, rainfall=94.3")
crop2, conf2 = test_model_with_inputs(78, 48, 22, 23.1, 63.7, 6.9, 94.3)
print(f"Predicted Crop: {crop2} (Confidence: {conf2:.2f}%)")
print()

print("N=119, P=25, K=51, temp=26.5, humidity=80.9, pH=6.3, rainfall=53.7")
crop3, conf3 = test_model_with_inputs(119, 25, 51, 26.5, 80.9, 6.3, 53.7)
print(f"Predicted Crop: {crop3} (Confidence: {conf3:.2f}%)")
print()

print("N=34, P=14, K=199, temp=22.8, humidity=93.4, pH=5.8, rainfall=115.2")
crop4, conf4 = test_model_with_inputs(34, 14, 199, 22.8, 93.4, 5.8, 115.2)
print(f"Predicted Crop: {crop4} (Confidence: {conf4:.2f}%)")
print()

print("N=80, P=50, K=40, temp=25, humidity=75, pH=6.8, rainfall=100")
crop5, conf5 = test_model_with_inputs(80, 50, 40, 25, 75, 6.8, 100)
print(f"Predicted Crop: {crop5} (Confidence: {conf5:.2f}%)")
print()
# Out:
# N=90, P=42, K=43, temp=20.88, humidity=82, pH=6.5, rainfall=202.94
# Predicted Crop: rice (Confidence: 97.88%)
#
# N=78, P=48, K=22, temp=23.1, humidity=63.7, pH=6.9, rainfall=94.3
# Predicted Crop: maize (Confidence: 98.32%)
#
# N=119, P=25, K=51, temp=26.5, humidity=80.9, pH=6.3, rainfall=53.7
# Predicted Crop: watermelon (Confidence: 100.00%)
#
# N=34, P=14, K=199, temp=22.8, humidity=93.4, pH=5.8, rainfall=115.2
# Predicted Crop: apple (Confidence: 43.50%)
#
# N=80, P=50, K=40, temp=25, humidity=75, pH=6.8, rainfall=100
# Predicted Crop: jute (Confidence: 47.50%)

# %%
import joblib
import numpy as np
import pandas as pd  # Import pandas

# Load trained model, scaler, and label encoder
best_model = joblib.load('crop_recommendation_model.pkl')
scaler = joblib.load('scaler.pkl')
label_encoder = joblib.load('label_encoder.pkl')

def test_model_with_inputs(N, P, K, temperature, humidity, ph, rainfall):
    # Create a pandas DataFrame with correct column names
    input_df = pd.DataFrame({
        'N': [N],
        'P': [P],
        'K': [K],
        'temperature': [temperature],
        'humidity': [humidity],
        'ph': [ph],
        'rainfall': [rainfall]
    })
    input_scaled = scaler.transform(input_df)  # No warning now
    prediction = best_model.predict(input_scaled)
    prediction_proba = best_model.predict_proba(input_scaled)
    predicted_crop = label_encoder.inverse_transform(prediction)[0]
    confidence = np.max(prediction_proba) * 100
    return predicted_crop, confidence

def single_prediction_crop():
    print("\nCROP RECOMMENDATION SYSTEM")
    try:
        N = float(input("Nitrogen (N): "))
        P = float(input("Phosphorus (P): "))
        K = float(input("Potassium (K): "))
        temperature = float(input("Temperature (°C): "))
        humidity = float(input("Humidity (%): "))
        ph = float(input("pH level: "))
        rainfall = float(input("Rainfall (mm): "))
        
        crop, confidence = test_model_with_inputs(N, P, K, temperature, humidity, ph, rainfall)
        
        print(f"\nRECOMMENDATION:")
        print(f"Recommended Crop: {crop.upper()}")
        print(f"Confidence: {confidence:.2f}%")
        if confidence > 90:
            print("High confidence prediction!")
        elif confidence > 75:
            print("Moderate confidence prediction")
        else:
            print("Low confidence - consider checking input values")
    except ValueError:
        print("Please enter valid numeric values")

# Run for a single-user test input
single_prediction_crop()
# Out:
# CROP RECOMMENDATION SYSTEM
#
# RECOMMENDATION:
# Recommended Crop: RICE
# Confidence: 97.88%
# High confidence prediction!
